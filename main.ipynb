# %%
import cv2 
import numpy as np

prototxt_path = 'models/MobileNetSSD_deploy.prototxt.txt'
model_path = 'models/MobileNetSSD_deploy.caffemodel'
min_confidence = 0.2

classes = ["background", "aeroplane", "bicycle", "bird", "keyboard", "bottle", "bus", "headphones", "cat", "chair", "cow", 
           "diningtable", "dog", "horse", "motorbike", "person", "headphones", "sheep", "bag", "train", "tv/laptop/mobile"]
np.random.seed(543210)
colors = np.random.uniform(0, 255, size=(len(classes), 3))

net = cv2.dnn.readNetFromCaffe(prototxt_path, model_path)

cap = cv2.VideoCapture(0)

while True:
    ret, image = cap.read()
    if not ret:
        break

    # Resize the frame to a smaller size
    resized_image = cv2.resize(image, (320, 240))
    
    height, width = resized_image.shape[0], resized_image.shape[1]
    blob = cv2.dnn.blobFromImage(cv2.resize(resized_image, (300, 300)), 0.007843, (300, 300), 127.5)
    net.setInput(blob)
    detected_objects = net.forward()

    for i in range(detected_objects.shape[2]):
        confidence = detected_objects[0, 0, i, 2]
        if confidence > min_confidence:
            class_index = int(detected_objects[0, 0, i, 1])
            upper_left_x = int(detected_objects[0, 0, i, 3] * width)
            upper_left_y = int(detected_objects[0, 0, i, 4] * height)
            lower_right_x = int(detected_objects[0, 0, i, 5] * width)
            lower_right_y = int(detected_objects[0, 0, i, 6] * height)
            prediction_text = f"{classes[class_index]}: {confidence:.2f}%"
            cv2.rectangle(resized_image, (upper_left_x, upper_left_y), (lower_right_x, lower_right_y), colors[class_index], 3)
            cv2.putText(resized_image, prediction_text, (upper_left_x, upper_left_y - 15 if upper_left_y > 30 else upper_left_y + 15),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, colors[class_index], 2)

    cv2.imshow("Detected Objects", resized_image)
    key = cv2.waitKey(1)  # Shorter delay for smoother video
    if key == ord('q'):  # Press 'q' to exit the loop
        break

cap.release()  # Release the video capture object
cv2.destroyAllWindows()  # Close all OpenCV windows
# Out:
# 2024-07-27 16:13:44.230 python[12224:379734] NSSoftLinking - The function 'SLSTransactionSetWindowTags' can't be found in the (null) framework.
# 2024-07-27 16:13:44.231 python[12224:379734] NSSoftLinking - The function 'SLSTransactionReorderWindows' can't be found in the (null) framework.
# 2024-07-27 16:13:44.232 python[12224:379734] NSSoftLinking - The function 'SLSTransactionOrderWindowGroupFrontConditionally' can't be found in the (null) framework.
# 2024-07-27 16:13:44.372 python[12224:379734] NSSoftLinking - The function 'SLSTransactionEnsureSpaceSwitchToActiveProcess' can't be found in the (null) framework.
